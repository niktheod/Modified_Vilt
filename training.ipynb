# %%
from train import train
from collections import defaultdict

# %%
hyperparameters = {"frac_keep": 0.1,
                   "batch_size": 8,
                   "epochs": 10,
                   "lr": 0.0001,
                   "weight_decay": 0.1}

hyperparameters = defaultdict(lambda: None, hyperparameters)

# %%
train(hyperparameters=hyperparameters,
      dataset="isvqa",
      qa_path="/home/nikostheodoridis/isvqa",
      nuscenes_path="/home/nikostheodoridis/nuscenes/samples",
      path_to_save_results="/home/nikostheodoridis/Dissertation/Results",
      path_to_save_model="/home/nikostheodoridis/Trained Models")
# Out:
# /home/nikostheodoridis/.local/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Epoch: 1
# 	Training...
# 		Batch 1/488: Loss 461.1744384765625 | Accuracy: 0.0%
# 		Batch 2/488: Loss 436.08172607421875 | Accuracy: 0.0%
# 		Batch 3/488: Loss 412.179443359375 | Accuracy: 0.0%
# 		Batch 4/488: Loss 389.8428039550781 | Accuracy: 0.0%
# 		Batch 5/488: Loss 367.29461669921875 | Accuracy: 0.0%
# 		Batch 6/488: Loss 348.9666748046875 | Accuracy: 0.0%
# 		Batch 7/488: Loss 328.4747314453125 | Accuracy: 0.0%
# 		Batch 8/488: Loss 308.9134826660156 | Accuracy: 0.0%
# 		Batch 9/488: Loss 287.7399597167969 | Accuracy: 0.0%
# 		Batch 10/488: Loss 279.005859375 | Accuracy: 0.0%
# 		Batch 11/488: Loss 261.0828857421875 | Accuracy: 0.0%
# ...
